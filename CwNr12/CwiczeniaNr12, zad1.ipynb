# %%
library(readr)

# %%
zamowienia <- read.csv("C:/Users/Adam/Desktop/repo/wd_dswp/lab_10/data/zamowienia.csv", sep=';')
head(zamowienia)
# Out:
#   ď.żKraj Sprzedawca Data.zamowienia idZamowienia Utarg
# 1 Polska  Kowalski   2003-07-16      10248         440.00
# 2 Polska  SowiĹ„ski  2003-07-10      10249        1863.40
# 3 Niemcy  Peacock    2003-07-12      10250        1552.60
# 4 Niemcy  Leverling  2003-07-15      10251         654.06
# 5 Niemcy  Peacock    2003-07-11      10252        3597.90
# 6 Niemcy  Leverling  2003-07-16      10253        1444.80

# %%
plot(zamowienia)
# Out:
# plot without title

# %%
plot(zamowienia$Sprzedawca, zamowienia$Kraj)
# Out:
# plot without title

# %%
boxplot(zamowienia[, 0:5])
# Out:
# plot without title
