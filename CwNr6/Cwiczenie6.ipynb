# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
# %matplotlib inline

# %%
# Zadanie 1
x=np.arange(1,20)
plt.plot(x,1/x, label="Krzywa funkcji f(x) = 1/x dla x ϵ [1, 20]")
plt.legend(loc="best")
plt.ylim(0,1)
plt.xlim(1,len(x))
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %%
# Zadanie 2
import pandas as pd
df=pd.read_csv('C:/Users/Adam/Desktop/repo/wd_dswp/lab_6/data/zamowienia.csv', sep=';')
df['Data zamowienia']=df['Data zamowienia'].astype('datetime64[ns]')
df=df[(df['Data zamowienia']>'2003-12-31') & (df['Data zamowienia']<'2005-01-01')]
df
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 132  Niemcy   Callahan      2004-01-16         10380  1313.82
# 144  Niemcy     Fuller      2004-01-01         10392  1440.00
# 145  Niemcy    Davolio      2004-01-03         10393  2556.95
# 146  Niemcy    Davolio      2004-01-03         10394   442.00
# 147  Polska   Sowiński      2004-01-03         10395  2122.92
# ..      ...        ...             ...           ...      ...
# 539  Niemcy     Fuller      2004-12-26         10787  2622.76
# 541  Niemcy    Davolio      2004-12-31         10789  3687.00
# 542  Polska   Sowiński      2004-12-26         10790   722.50
# 544  Niemcy    Davolio      2004-12-31         10792   399.85
# 553  Niemcy    Peacock      2004-12-31         10801  3026.85
#
# [399 rows x 5 columns]

# %%
merchants=df[df['Kraj']=='Polska']['Sprzedawca'].unique()
df.plot(figsize=(8,8));
plt.tight_layout(-15)
for i in range(len(merchants)):
    plt.subplot(2, 2, i+1)
    plt.plot(df[df['Sprzedawca']==merchants[i]].groupby(pd.Grouper(key='Data zamowienia', axis=0, freq='M')).count()['Sprzedawca'], label=merchants[i])
    plt.legend(title='Sprzedawca')
    plt.title('Ilość wykonanych transakcji w 2004 roku')
    plt.xlabel('Data')
    plt.ylabel('Ilość wykonanych transakcji')
    plt.ylim(0,8)
    plt.xlim([datetime.date(2004, 1, 1), datetime.date(2004, 12, 31)])
    plt.xticks(rotation=45)
# Out:
# C:\Users\Adam\AppData\Local\Temp/ipykernel_7776/2541365945.py:3: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   plt.tight_layout(-15)

# %%
# Zadanie 3
df=pd.read_excel('C:/Users/Adam/Desktop/repo/wd_dswp/lab_6/data/imiona.xlsx')
df.head()
# Out:
#     Rok     Imie  Liczba Plec
# 0  2000    JAKUB   14497    M
# 1  2000  MATEUSZ   11454    M
# 2  2000   KACPER    8898    M
# 3  2000   MICHAŁ    8498    M
# 4  2000   PATRYK    7743    M

# %%
# Zad 3, pkt a)
births=[df['Plec'].where(df['Plec']=='M').count(),df['Plec'].where(df['Plec']=='K').count()]
plt.bar(df['Plec'].unique(), births)
plt.title('Całkowita liczba urodzeń z podziałem na płeć')
plt.xlabel('Płeć')
plt.ylabel('Ilość urodzeń')
plt.show()

# %%
# Zad 3, pkt b)
plt.plot(df['Rok'].unique(),  df[['Plec','Liczba', 'Rok']].where(df['Plec']=='M').groupby(['Plec','Rok']).count(), label='Mężczyźni')
plt.plot(df['Rok'].unique(),  df[['Plec','Liczba', 'Rok']].where(df['Plec']=='K').groupby(['Plec','Rok']).count(), label='Kobiety')
plt.legend(title='Płeć')
plt.title('Roczne liczby urodzeń z podziałem na płeć')
plt.xlabel('Rok')
plt.ylabel('Ilość urodzeń')
plt.xticks(rotation=45)
plt.show()

# %%
# Zad 3, pkt c)
plt.bar(df['Rok'].unique(), df[['Liczba', 'Rok']].groupby(['Rok']).count()['Liczba'])
plt.title('Roczne liczby urodzeń')
plt.xlabel('Rok')
plt.ylabel('Ilość urodzeń')
plt.xticks(rotation=45)
plt.show()

# %%
# Zadanie 4
df =  pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', 
                 names=['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Class'])
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(df['Sepal_Length'], df['Sepal_Width'], c='g', s=abs(df['Sepal_Length']-df['Sepal_Width']))

# %%
# Zadanie 5
df=pd.read_csv('C:/Users/Adam/Desktop/repo/wd_dswp/lab_6/data/zamowienia.csv', sep=';')
df
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16         10248   440.00
# 1    Polska   Sowiński      2003-07-10         10249  1863.40
# 2    Niemcy    Peacock      2003-07-12         10250  1552.60
# 3    Niemcy  Leverling      2003-07-15         10251   654.06
# 4    Niemcy    Peacock      2003-07-11         10252  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       King      2005-04-30         11048   525.00
# 795  Niemcy  Leverling      2005-05-01         11052  1332.00
# 796  Niemcy     Fuller      2005-04-29         11053  3055.00
# 797  Niemcy   Callahan      2005-05-01         11056  3740.00
# 798  Niemcy  Leverling      2005-05-01         11057    45.00
#
# [799 rows x 5 columns]

# %%
plt.pie(df[['Sprzedawca', 'idZamowienia']].groupby(['Sprzedawca']).count()['idZamowienia'], labels=df['Sprzedawca'].unique(),
       autopct=lambda pct: "{:.1f}%".format(pct), textprops=dict(color="black"), shadow=True, explode=(0, 0, 0, 0, 0, 0, 0.2, 0, 0))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Zadanie 6
df=pd.read_excel('C:/Users/Adam/Desktop/repo/wd_dswp/lab_6/data/ludnosc.xlsx')
df=df[['Kraj', 2017]].head(10)
df
# Out:
#                        Kraj          2017
# 0  Chińska Republika Ludowa  1.379303e+09
# 1                     Indie  1.281936e+09
# 2           Unia Europejska  5.161954e+08
# 3         Stany Zjednoczone  3.266258e+08
# 4                 Indonezja  2.605807e+08
# 5                  Brazylia  2.073534e+08
# 6                  Pakistan  2.049249e+08
# 7                   Nigeria  1.906323e+08
# 8                Bangladesz  1.578266e+08
# 9                     Rosja  1.422575e+08

# %%
class BubbleChart:
    def __init__(self, area, bubble_spacing=0):
        area = np.asarray(area)
        r = np.sqrt(area / np.pi)

        self.bubble_spacing = bubble_spacing
        self.bubbles = np.ones((len(area), 4))
        self.bubbles[:, 2] = r
        self.bubbles[:, 3] = area
        self.maxstep = 2 * self.bubbles[:, 2].max() + self.bubble_spacing
        self.step_dist = self.maxstep / 2

        length = np.ceil(np.sqrt(len(self.bubbles)))
        grid = np.arange(length) * self.maxstep
        gx, gy = np.meshgrid(grid, grid)
        self.bubbles[:, 0] = gx.flatten()[:len(self.bubbles)]
        self.bubbles[:, 1] = gy.flatten()[:len(self.bubbles)]

        self.com = self.center_of_mass()

    def center_of_mass(self):
        return np.average(
            self.bubbles[:, :2], axis=0, weights=self.bubbles[:, 3]
        )

    def center_distance(self, bubble, bubbles):
        return np.hypot(bubble[0] - bubbles[:, 0],
                        bubble[1] - bubbles[:, 1])

    def outline_distance(self, bubble, bubbles):
        center_distance = self.center_distance(bubble, bubbles)
        return center_distance - bubble[2] - \
            bubbles[:, 2] - self.bubble_spacing

    def check_collisions(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return len(distance[distance < 0])

    def collides_with(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        idx_min = np.argmin(distance)
        return idx_min if type(idx_min) == np.ndarray else [idx_min]

    def collapse(self, n_iterations=50):
        for _i in range(n_iterations):
            moves = 0
            for i in range(len(self.bubbles)):
                rest_bub = np.delete(self.bubbles, i, 0)
                dir_vec = self.com - self.bubbles[i, :2]

                dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))

                new_point = self.bubbles[i, :2] + dir_vec * self.step_dist
                new_bubble = np.append(new_point, self.bubbles[i, 2:4])

                if not self.check_collisions(new_bubble, rest_bub):
                    self.bubbles[i, :] = new_bubble
                    self.com = self.center_of_mass()
                    moves += 1
                else:
                    for colliding in self.collides_with(new_bubble, rest_bub):
                        dir_vec = rest_bub[colliding, :2] - self.bubbles[i, :2]
                        dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                        orth = np.array([dir_vec[1], -dir_vec[0]])
                        new_point1 = (self.bubbles[i, :2] + orth *
                                      self.step_dist)
                        new_point2 = (self.bubbles[i, :2] - orth *
                                      self.step_dist)
                        dist1 = self.center_distance(
                            self.com, np.array([new_point1]))
                        dist2 = self.center_distance(
                            self.com, np.array([new_point2]))
                        new_point = new_point1 if dist1 < dist2 else new_point2
                        new_bubble = np.append(new_point, self.bubbles[i, 2:4])
                        if not self.check_collisions(new_bubble, rest_bub):
                            self.bubbles[i, :] = new_bubble
                            self.com = self.center_of_mass()

            if moves / len(self.bubbles) < 0.1:
                self.step_dist = self.step_dist / 2

    def plot(self, ax, labels, colors):
        for i in range(len(self.bubbles)):
            circ = plt.Circle(
                self.bubbles[i, :2], self.bubbles[i, 2], color=colors[i])
            ax.add_patch(circ)
            ax.text(*self.bubbles[i, :2], labels[i],
                    horizontalalignment='center', verticalalignment='center')


bubble_chart = BubbleChart(area=df[2017],
                           bubble_spacing=0.1)

bubble_chart.collapse()

fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"))
bubble_chart.plot(
    ax, df['Kraj'], ['#5A69AF', '#579E65', '#F9C784', '#FC944A', '#F24C00', '#00B825','#5A69AF', '#579E65', '#F9C784', '#FC944A', '#F24C00', '#00B825'])
ax.axis("off")
ax.relim()
ax.autoscale_view()
ax.set_title('Ludność')

plt.show()
