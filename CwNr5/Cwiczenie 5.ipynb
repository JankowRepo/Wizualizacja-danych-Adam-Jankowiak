# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

# %%
# Zadanie 1
df = pd.read_csv('C:/Users/Adam/Desktop/BL-Flickr-Images-Book.csv')
df
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %%
df.shape
# Out:
# (8287, 15)

# %%
# Usunięcie kolumn których wartości to tylko NaN
df = df.dropna(axis='columns', how ='all')
df.head()
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
df.shape
# Out:
# (8287, 12)

# %%
# Sprawdzanie kolejnych kolumn pod kątem ilości brakujących wartości
count_nan = len(df['Edition Statement']) - df['Edition Statement'].count()
count_nan
# Out:
# 7514

# %%
count_nan = len(df['Place of Publication']) - df['Place of Publication'].count()
count_nan
# Out:
# 0

# %%
count_nan = len(df['Date of Publication']) - df['Date of Publication'].count()
count_nan
# Out:
# 181

# %%
count_nan = len(df['Publisher']) - df['Publisher'].count()
count_nan
# Out:
# 4195

# %%
count_nan = len(df['Title']) - df['Title'].count()
count_nan
# Out:
# 0

# %%
count_nan = len(df['Author']) - df['Author'].count()
count_nan
# Out:
# 1778

# %%
count_nan = len(df['Contributors']) - df['Contributors'].count()
count_nan
# Out:
# 0

# %%
count_nan = len(df['Former owner']) - df['Former owner'].count()
count_nan
# Out:
# 8286

# %%
count_nan = len(df['Issuance type']) - df['Issuance type'].count()
count_nan
# Out:
# 0

# %%
count_nan = len(df['Flickr URL']) - df['Flickr URL'].count()
count_nan
# Out:
# 0

# %%
count_nan = len(df['Shelfmarks']) - df['Shelfmarks'].count()
count_nan
# Out:
# 0

# %%
# Usunięcie kolumn które mają bardzo dużo wartości brakujących
df = df.drop('Publisher', 1)
df = df.drop('Edition Statement', 1)
df = df.drop('Author', 1)
df = df.drop('Former owner', 1)
# Out:
# C:\Users\Adam\AppData\Local\Temp/ipykernel_17996/3579674490.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Publisher', 1)
# C:\Users\Adam\AppData\Local\Temp/ipykernel_17996/3579674490.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Edition Statement', 1)
# C:\Users\Adam\AppData\Local\Temp/ipykernel_17996/3579674490.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Author', 1)
# C:\Users\Adam\AppData\Local\Temp/ipykernel_17996/3579674490.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Former owner', 1)

# %%
df.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                                                Title  \
# 0                  Walter Forbes. [A novel.] By A. A
# 1  All for Greed. [A novel. The dedication signed...
# 2  Love the Avenger. By the author of “All for Gr...
# 3  Welsh Sketches, chiefly ecclesiastical, to the...
# 4  [The World in which I live, and my place in it...
#
#                                    Contributors Issuance type  \
# 0                               FORBES, Walter.   monographic
# 1  BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# 2  BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# ...

# %%
# Zadanie 2
# Sprawdzenie czy kolumna Idenifier posiada jedynie wartości unikalne
duplicates = df['Identifier'].duplicated().any()
duplicates
# Out:
# False

# %%
# Zamiana kolumny za index
df.set_index('Identifier', inplace=True)
df.head()
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 206                           London         1879 [1878]
# 216         London; Virtue & Yorston                1868
# 218                           London                1869
# 472                           London                1851
# 480                           London                1857
#
#                                                         Title  \
# Identifier
# 206                         Walter Forbes. [A novel.] By A. A
# 216         All for Greed. [A novel. The dedication signed...
# 218         Love the Avenger. By the author of “All for Gr...
# 472         Welsh Sketches, chiefly ecclesiastical, to the...
# 480         [The World in which I live, and my place in it...
#
#                                             Contributors Issuance type  \
# Identifier
# 206                                      FORBES, Walter.   monographic
# ...

# %%
# Podmiana kolumny, zamiana wartości w tej kolumnie na liczbowe
df['Date of Publication'] = df['Date of Publication'].str.extract(r'(\d{4})')
df['Date of Publication'] = df['Date of Publication'].fillna(0)
df['Date of Publication'] = df['Date of Publication'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8287 entries, 206 to 4160339
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Place of Publication  8287 non-null   object
#  1   Date of Publication   8287 non-null   int32
#  2   Title                 8287 non-null   object
#  3   Contributors          8287 non-null   object
#  4   Issuance type         8287 non-null   object
#  5   Flickr URL            8287 non-null   object
#  6   Shelfmarks            8287 non-null   object
# dtypes: int32(1), object(6)
# memory usage: 485.6+ KB

# %%
# Sprawdzenie ilości wartości unikalnych w kolumnie Place of Publication
df['Place of Publication'].nunique()
# Out:
# 1441

# %%
# Sprawdzenie wszystkich wartości unikalnych w kolumnie Place of Publication z ilością znaków większą od 10
[x for x in df['Place of Publication'].unique() if len(x) > 10]
# Out:
# ['London; Virtue & Yorston',
#  'pp. 40. G. Bryan & Co: Oxford, 1898',
#  'Christiania',
#  'Puerto-Rico',
#  'pp. 40. W. Cann: Plymouth, [1876?]',
#  'St. Petersburg',
#  'Carlstad, Stockholm',
#  'D. Appleton & Co',
#  'Санктпетербургъ',
#  'Ἐν Κερκυρᾳ',
#  'Cambridge, [Mass.]',
#  'Edinburgh & London',
#  'Edinburgh; John Murray',
#  'Philadelphia',
#  'pp. vi. 216. Hatchards: London, 1888',
#  'Londini Gothorum',
#  'J. Vincent; London',
#  'Westminster',
#  'London & New York',
#  'London; Oxford',
#  'Great Yarmouth',
#  'New York, London',
#  'pp. 64. W. Cann: Plymouth, [1870?]',
#  'Meriden, Conn',
#  'Paris; Moulins',
#  'T. C. Newby; London',
#  'pp. 95. Erskine Macdonald: London, 1921',
#  'pp. xi. 59. J. Parker & Co.: Oxford, [1900.]',
#  'Kolozsvártt',
#  'Hartford, Conn',
#  'Springfield, Mass',
#  'Basingstoke',
#  'Barton-upon-Humber',
#  'Edinburgh; reprinted by B. Dewhirst',
#  'Saint-Dizier',
#  'Cooperstown, N.Y',
#  'Newark, N.J',
#  'Windsor, Vt',
# ...

# %%
# Zastępowanie nazw niektórych miast w kolumnie Place of Publication na krótsze
df['Place of Publication'] = pd.np.where(df['Place of Publication'].str.contains("London"), "London",
                             pd.np.where(df['Place of Publication'].str.contains("Oxford"), "Oxford",
                             pd.np.where(df['Place of Publication'].str.contains("Cambridge"), "Cambridge",
                             pd.np.where(df['Place of Publication'].str.contains("Edinburgh"), "Edinburgh",
                             pd.np.where(df['Place of Publication'].str.contains("Stockholm"), "Stockholm",   
                             pd.np.where(df['Place of Publication'].str.contains("Plymouth"), "Plymouth",   
                             pd.np.where(df['Place of Publication'].str.contains("Barnstaple"), "Barnstaple",
                             pd.np.where(df['Place of Publication'].str.contains("Portland "), "Portland ",
                             pd.np.where(df['Place of Publication'].str.contains("Belfast"), "Belfast",
                             pd.np.where(df['Place of Publication'].str.contains("Санктпетербургъ"), "Санктпетербургъ",
                             pd.np.where(df['Place of Publication'].str.contains("Paris"), "Paris",
                             pd.np.where(df['Place of Publication'].str.contains("Santiago"), "Santiago",
                             pd.np.where(df['Place of Publication'].str.contains("Manchester"), "Manchester",
                             pd.np.where(df['Place of Publication'].str.contains("Hammersmith"), "Hammersmith",
                             pd.np.where(df['Place of Publication'].str.contains("Berlin"), "Berlin",
                             pd.np.where(df['Place of Publication'].str.contains("Perth"), "Perth",
                             pd.np.where(df['Place of Publication'].str.contains("Penzance"), "Penzance",
                             pd.np.where(df['Place of Publication'].str.contains("Los Angeles"), "Los Angeles",
                             pd.np.where(df['Place of Publication'].str.contains("West Milton"), "West Milton",
                             pd.np.where(df['Place of Publication'].str.contains("Newport"), "Newport",
                             pd.np.where(df['Place of Publication'].str.contains("Rotterdam"), "Rotterdam",
                             pd.np.where(df['Place of Publication'].str.contains("Glasgow"), "Glasgow",       
                             pd.np.where(df['Place of Publication'].str.contains("New York"), "New York",
                             pd.np.where(df['Place of Publication'].str.contains("Pesth"), "Pesth",
                             pd.np.where(df['Place of Publication'].str.contains("Dublin"), "Dublin",
                             pd.np.where(df['Place of Publication'].str.contains("Baltimore"), "Baltimore",
                             pd.np.where(df['Place of Publication'].str.contains("Санктпетербург"), "Санктпетербург",
                             pd.np.where(df['Place of Publication'].str.contains("Leamington"), "Leamington",
                             pd.np.where(df['Place of Publication'].str.contains("Kingston"), "Kingston",
                             pd.np.where(df['Place of Publication'].str.contains("Augusta"), "Augusta",
                             pd.np.where(df['Place of Publication'].str.contains("Potsdam"), "Potsdam",
                             pd.np.where(df['Place of Publication'].str.contains("Utrecht"), "Utrecht",     
                             pd.np.where(df['Place of Publication'].str.contains("Hamblen"), "Hamblen",
                             pd.np.where(df['Place of Publication'].str.contains("Melbourne"), "Melbourne",
                             pd.np.where(df['Place of Publication'].str.contains("Coventry"), "Coventry",
                             pd.np.where(df['Place of Publication'].str.contains("Leipzig"), "Leipzig",
                             pd.np.where(df['Place of Publication'].str.contains("Worcester"), "Worcester",
                             df['Place of Publication'])))))))))))))))))))))))))))))))))))))
# Out:
# C:\Users\Adam\AppData\Local\Temp/ipykernel_17996/4292828012.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   df['Place of Publication'] = pd.np.where(df['Place of Publication'].str.contains("London"), "London",
# C:\Users\Adam\AppData\Local\Temp/ipykernel_17996/4292828012.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(df['Place of Publication'].str.contains("Oxford"), "Oxford",
# C:\Users\Adam\AppData\Local\Temp/ipykernel_17996/4292828012.py:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(df['Place of Publication'].str.contains("Cambridge"), "Cambridge",
# ...

# %%
df['Place of Publication'].nunique()
# Out:
# 1081

# %%
df.to_csv('Normalised_BL-Flickr-Images-Book.csv', index=False)
